# %% [markdown]
# # Hadoop Streaming assignment 3: Name Count

# %% [markdown]
# Make WordCount program for all the names in the dataset. Name is a word with the following properties:
#
# 1. The first character is not a digit (other characters can be digits).
# 2. The first character is uppercase, all the other characters that are letters are lowercase.
# 3. There are less than 0.5% occurrences of this word, when this word regardless to its case appears in the dataset and the condition (2) is not met.
#
# Order by quantity, most popular first, output format:
#
#     name <tab> count
#
# The result is the 5th line in the output.
#
# The result on the sample dataset:
#
#     french 5742
#
# If you want to deploy the environment on your own machine, please use [bigdatateam/yarn-notebook](https://hub.docker.com/r/bigdatateam/yarn-notebook/) Docker container.

# %% [markdown]
# ## Step 1. Create first mapper and reducer

# %%
# %%writefile mapper1.py

import sys
import re

for line in sys.stdin:

    article_id, text = line.strip().split('\t', 1)

    try:
        words = re.split('\W*\s+\W*', text.strip())
        for word in words:
            cond1 = word[0].isalpha()
            cond2 = not word[0].islower() and word[1:].islower()

            if cond1:
                print("{}\t{:d}\t{:d}".format(word.lower(), 1, int(cond2)))
            
    except Exception as e:
        continue
# Out:
# Writing mapper1.py

# %%
# %%writefile reducer1.py

import sys

current_key = None
word_total = 0
name_total = 0

for line in sys.stdin:
    try:
        key, word_count, name_count = line.strip().split('\t', 2)
        word_count = int(word_count)
        name_count = int(name_count)
        
        if current_key != key:
            if current_key:
                print("{}\t{:d}\t{:d}".format(current_key, name_total, word_total))
                
            current_key = key
            word_total = 0
            name_total = 0
        
        word_total += word_count
        name_total += name_count
        
    except Exception as e:
        print(e)
        continue  

if current_key:
    print("{}\t{:d}\t{:d}".format(current_key, name_total, word_total))
# Out:
# Writing reducer1.py

# %% [markdown]
# ## Step 2. Create second mapper and reducer

# %%
# %%writefile mapper2.py

import sys

current_key = None
word_total = 0
name_total = 0

for line in sys.stdin:
    try:
        key, name_count, word_count = line.strip().split('\t', 2)
        word_count = int(word_count)
        name_count = int(name_count)
        
        if current_key != key:
            if current_key:
                print("{}\t{}\t{}".format(name_total, word_total, current_key))
                
            current_key = key
            word_total = 0
            name_total = 0
        
        word_total += word_count
        name_total += name_count
        
    except ValueError as e:
        print(e)
        continue    

if current_key:
    print("{}\t{}\t{}".format(name_total, word_total, current_key))
# Out:
# Writing mapper2.py

# %%
# %%writefile reducer2.py

import sys

total_count = 0
total_caps = 0
current_word = None

for line in sys.stdin:
    try:
        caps_count, count, key = line.strip().split('\t', 2)
        count = int(count)
        caps_count = int(caps_count)
        
        if key != current_word:
            
            if current_word and float(total_caps) / float(total_count) >= 0.995: 
                print("{}\t{:d}".format(current_word, total_caps))
            
            total_count = 0
            total_caps = 0
            current_word = key


        total_caps += caps_count
        total_count += count

    except Exception as e:
        print e
        continue
        
if current_word and float(total_caps) / float(total_count) >= 0.995: 
    print("{}\t{:d}".format(current_word, total_caps))
# Out:
# Writing reducer2.py

# %% [markdown]
# ## Step 3. Bash commands
#
# <b> Hint: </b> For printing the exact row you may use basic UNIX commands. For instance, sed/head/tail/... (if you know other commands, you can use them).
#
# To run both jobs, you must use two consecutive yarn-commands. Remember that the input for the second job is the ouput for the first job.

# %%
# %%bash
#
# OUT_DIR_1="assignment3_1_"$(date +"%s%6N")
# OUT_DIR_2="assignment3_2_"$(date +"%s%6N")
# NUM_REDUCERS=4
#
# # Code for your first job
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -files mapper1.py,reducer1.py \
#     -mapper 'python2 mapper1.py' \
#     -reducer 'python2 reducer1.py' \
#     -numReduceTasks ${NUM_REDUCERS} \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR_1} > /dev/null
#
# # Code for your second job
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.output.key.comparator.class=org.apache.hadoop.mapreduce.lib.partition.KeyFieldBasedComparator \
#     -D mapreduce.partition.keycomparator.options="-k1,3nr" \
#     -files mapper2.py,reducer2.py \
#     -mapper 'python2 mapper2.py' \
#     -reducer 'python2 reducer2.py' \
#     -numReduceTasks 1 \
#     -input ${OUT_DIR_1} \
#     -output ${OUT_DIR_2} > /dev/null
#
# # Code for obtaining the results
# hdfs dfs -cat ${OUT_DIR_2}/part-00000 | sed -n "5p;8q"
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_1}* > /dev/null
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_2}* > /dev/null
# Out:
# french	5740
# 19/06/15 15:31:58 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/06/15 15:31:58 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/06/15 15:32:00 INFO mapred.FileInputFormat: Total input files to process : 1
# 19/06/15 15:32:01 INFO mapreduce.JobSubmitter: number of splits:2
# 19/06/15 15:32:01 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1560606164948_0003
# 19/06/15 15:32:01 INFO impl.YarnClientImpl: Submitted application application_1560606164948_0003
# 19/06/15 15:32:01 INFO mapreduce.Job: The url to track the job: http://307727ece75b:8088/proxy/application_1560606164948_0003/
# 19/06/15 15:32:01 INFO mapreduce.Job: Running job: job_1560606164948_0003
# 19/06/15 15:32:11 INFO mapreduce.Job: Job job_1560606164948_0003 running in uber mode : false
# 19/06/15 15:32:11 INFO mapreduce.Job:  map 0% reduce 0%
# 19/06/15 15:32:29 INFO mapreduce.Job:  map 38% reduce 0%
# 19/06/15 15:32:35 INFO mapreduce.Job:  map 45% reduce 0%
# 19/06/15 15:32:41 INFO mapreduce.Job:  map 65% reduce 0%
# 19/06/15 15:32:47 INFO mapreduce.Job:  map 82% reduce 0%
# 19/06/15 15:32:49 INFO mapreduce.Job:  map 100% reduce 0%
# 19/06/15 15:33:08 INFO mapreduce.Job:  map 100% reduce 18%
# 19/06/15 15:33:11 INFO mapreduce.Job:  map 100% reduce 40%
# 19/06/15 15:33:12 INFO mapreduce.Job:  map 100% reduce 61%
# 19/06/15 15:33:14 INFO mapreduce.Job:  map 100% reduce 87%
# 19/06/15 15:33:18 INFO mapreduce.Job:  map 100% reduce 95%
# 19/06/15 15:33:20 INFO mapreduce.Job:  map 100% reduce 98%
# 19/06/15 15:33:22 INFO mapreduce.Job:  map 100% reduce 100%
# 19/06/15 15:33:23 INFO mapreduce.Job: Job job_1560606164948_0003 completed successfully
# 19/06/15 15:33:23 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=280966143
# 		FILE: Number of bytes written=422249996
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=5484188
# 		HDFS: Number of read operations=18
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=8
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=4
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=72543
# 		Total time spent by all reduces in occupied slots (ms)=101080
# 		Total time spent by all map tasks (ms)=72543
# 		Total time spent by all reduce tasks (ms)=101080
# 		Total vcore-milliseconds taken by all map tasks=72543
# 		Total vcore-milliseconds taken by all reduce tasks=101080
# 		Total megabyte-milliseconds taken by all map tasks=74284032
# 		Total megabyte-milliseconds taken by all reduce tasks=103505920
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=11472777
# 		Map output bytes=117525361
# 		Map output materialized bytes=140470972
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=369512
# 		Reduce shuffle bytes=140470972
# 		Reduce input records=11472777
# 		Reduce output records=369512
# 		Spilled Records=34418331
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=1631
# 		CPU time spent (ms)=139140
# 		Physical memory (bytes) snapshot=1301753856
# 		Virtual memory (bytes) snapshot=11798040576
# 		Total committed heap usage (bytes)=908066816
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=5484188
# 19/06/15 15:33:23 INFO streaming.StreamJob: Output directory: assignment3_1_1560612715204192
# 19/06/15 15:33:26 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/06/15 15:33:26 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/06/15 15:33:27 INFO mapred.FileInputFormat: Total input files to process : 4
# 19/06/15 15:33:27 INFO mapreduce.JobSubmitter: number of splits:4
# 19/06/15 15:33:28 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1560606164948_0004
# 19/06/15 15:33:28 INFO impl.YarnClientImpl: Submitted application application_1560606164948_0004
# 19/06/15 15:33:28 INFO mapreduce.Job: The url to track the job: http://307727ece75b:8088/proxy/application_1560606164948_0004/
# 19/06/15 15:33:28 INFO mapreduce.Job: Running job: job_1560606164948_0004
# 19/06/15 15:33:37 INFO mapreduce.Job: Job job_1560606164948_0004 running in uber mode : false
# 19/06/15 15:33:37 INFO mapreduce.Job:  map 0% reduce 0%
# 19/06/15 15:33:52 INFO mapreduce.Job:  map 100% reduce 0%
# 19/06/15 15:34:08 INFO mapreduce.Job:  map 100% reduce 100%
# 19/06/15 15:34:08 INFO mapreduce.Job: Job job_1560606164948_0004 completed successfully
# 19/06/15 15:34:08 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=6223239
# 		FILE: Number of bytes written=13146006
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=5484696
# 		HDFS: Number of bytes written=1484298
# 		HDFS: Number of read operations=15
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=4
# 		Launched reduce tasks=1
# 		Data-local map tasks=4
# 		Total time spent by all maps in occupied slots (ms)=50519
# 		Total time spent by all reduces in occupied slots (ms)=13324
# 		Total time spent by all map tasks (ms)=50519
# 		Total time spent by all reduce tasks (ms)=13324
# 		Total vcore-milliseconds taken by all map tasks=50519
# 		Total vcore-milliseconds taken by all reduce tasks=13324
# 		Total megabyte-milliseconds taken by all map tasks=51731456
# 		Total megabyte-milliseconds taken by all reduce tasks=13643776
# 	Map-Reduce Framework
# 		Map input records=369512
# 		Map output records=369512
# 		Map output bytes=5484198
# 		Map output materialized bytes=6223257
# 		Input split bytes=508
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=935
# 		Reduce shuffle bytes=6223257
# 		Reduce input records=369512
# 		Reduce output records=133518
# 		Spilled Records=739024
# 		Shuffled Maps =4
# 		Failed Shuffles=0
# 		Merged Map outputs=4
# 		GC time elapsed (ms)=645
# 		CPU time spent (ms)=11000
# 		Physical memory (bytes) snapshot=1228419072
# 		Virtual memory (bytes) snapshot=9807384576
# 		Total committed heap usage (bytes)=906493952
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=5484188
# 	File Output Format Counters
# 		Bytes Written=1484298
# 19/06/15 15:34:08 INFO streaming.StreamJob: Output directory: assignment3_2_1560612715205499
# cat: Unable to write to output stream.
